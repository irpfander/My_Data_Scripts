# %%
import pandas as pd 
import statsmodels.formula.api as smf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.ticker import ScalarFormatter
import matplotlib.font_manager as font_manager
import os
import seaborn as sns
import statsmodels as sm
import math 
from matplotlib.lines import Line2D
from scipy import stats
from scipy.stats import f_oneway

# %% [markdown]
# ## Isometric Log Ratio Plot
#
# Data cleaning and transformation not included

# %%
aq_palette = ['#a8ddb5','#7bccc4','#4eb3d3','#2b8cbe', '#216c91', '#0868ac','#084081', '#063060']
ax1 = sns.JointGrid(height=3.33)

plt.setp(ax1.ax_joint.get_xticklabels(),fontsize=6)
plt.setp(ax1.ax_joint.get_yticklabels(),fontsize=6)

# dashed lines
ax1.ax_joint.axhline(y=2.9520375352397936, linestyle='--',linewidth=0.8, color = 'grey')
ax1.ax_joint.axhline(y=1.1092492790813162, linestyle='--',linewidth=0.8, color = 'grey')

ax1.ax_joint.axvline(x=4415.202041023325, linestyle='--',linewidth=0.8, color = 'grey')

ax1.ax_joint.axvline(x=2340.6600198104434, linestyle='--',linewidth=0.8, color = 'grey')


x, y = bhd_samp_mol["TOTAL DISSOLVED SOLIDS"], bhd_samp_mol['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc="grey", s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = "grey")
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = "grey")
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = "grey")
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = "grey")

x, y = prd_cogcc_mol["TOTAL DISSOLVED SOLIDS"], prd_cogcc_mol['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc="orange", s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = "orange")
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = "orange")
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = "orange")
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = "orange")

x, y = aq_dc["tds"], aq_dc['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[5], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[5])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[5])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[5])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[5])

x, y = aq_hp["tds"], aq_hp['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[6], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[6])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[6])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[6])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[6])

x, y = aq_lfhc["tds"], aq_lfhc['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[4], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[4])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[4])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[4])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[4])

x, y = aq_lfhu["tds"], aq_lfhu['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[3], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[3])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[3])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[3])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[3])

x, y = aq_qa["tds"], aq_qa['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[0], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[0])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[0])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[0])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[0])

x, y = aq_d["tds"], aq_d['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[1], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[1])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[1])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[1])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[1])

x, y = aq_a["tds"], aq_a['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[2], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[2])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[2])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[2])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[2])

x, y = UP_aq["TDS"], UP_aq['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc=aq_palette[7], s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = aq_palette[7])
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = aq_palette[7])
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color = aq_palette[7])
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = aq_palette[7])

x, y = prd_usgs_mol["TOTAL DISSOLVED SOLIDS"], prd_usgs_mol['Cl/SO4']
sns.scatterplot(x=x, y=y, ec='k', fc='#FF6666', s=10, linewidth=0.5, ax=ax1.ax_joint)
sns.kdeplot(x=x, linewidth=0.8, ax=ax1.ax_marg_x, color = '#FF6666')
sns.kdeplot(y=y, linewidth=0.8, ax=ax1.ax_marg_y,color = '#FF6666')
ax1.ax_marg_x.axvline(x=x.median(), linestyle='--',linewidth=0.8, color ='#FF6666')
ax1.ax_marg_y.axhline(y=y.median(), linestyle='--',linewidth=0.8, color = '#FF6666')

#add mixing curve
bbox_props = dict(boxstyle="larrow", fc="w", ec="0.5", alpha=0.9)
x, y = mixing_curve_tds["TDS"], mixing_curve_tds['ilr Cl/SO4']
sns.lineplot(x=x, y=y, color='k', markers=True,  linewidth=3, ax=ax1.ax_joint)
sns.lineplot(x=x, y=y, color='w', markers=True,  linewidth=1, ax=ax1.ax_joint)

ax1.ax_joint.set_ylabel('$ \dfrac{1}{\sqrt{2}} $ ln $\dfrac{[Cl]}{[SO4]}$', fontsize = 6)
ax1.ax_joint.set_xlabel('TDS (mg/L)', fontsize = 6)

ax1.ax_joint.set(xscale="log")
plt.savefig(os.path.join(fig_dir,'.pdf'), bbox_inches='tight')
plt.savefig(os.path.join(fig_dir,'.png'), bbox_inches='tight')
